# %%
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
words = open('Dataset/test.txt', 'r').read().split()

# %%
words
# Out:
# ['Prólogo',
#  'Frente',
#  'a',
#  'la',
#  'joven',
#  'y',
#  'a',
#  'su',
#  'pequeña',
#  'hermana,',
#  'el',
#  'caballero',
#  'en',
#  'armadura',
#  'levantó',
#  'su',
#  'espada.',
#  'Tener',
#  'piedad',
#  'es',
#  'tomar',
#  'una',
#  'vida',
#  'de',
#  'un',
#  'sólo',
#  'golpe.',
#  'La',
#  'espada,',
#  'bañada',
#  'por',
#  'la',
#  'luz',
#  'del',
#  'sol,',
#  'brilló',
#  'en',
#  'el',
#  'cielo.',
#  'La',
#  'joven',
#  'cerró',
#  'los',
#  'ojos',
#  'y',
#  'se',
#  'mordió',
#  'el',
#  'labio',
#  'inferior.',
#  'Su',
#  'expresión',
#  'mostraba',
#  'que',
#  'nunca',
#  'quiso',
#  'que',
#  'pasara',
#  'algo',
#  'como',
#  'esto.',
#  'Simplemente',
#  'lo',
#  'estaba',
#  'aceptando',
#  'porque',
#  'no',
#  'había',
#  'nada',
#  'que',
#  'pudiera',
#  'hacer.',
#  'Si',
#  'tuviera',
#  'algún',
#  'poder,',
#  'podría',
#  'usarlo',
#  'contra',
#  'el',
#  'hombre',
#  'frente',
#  'a',
#  'ella',
#  'y',
#  'escaparía,',
# ...

# %%
N = torch.zeros((100, 100), dtype = torch.int16)

# %%
b = {}

# %%
for word in words:
        xs.append(word)
